# %%
# Parse and read the csv files
import pandas as pd

# Replace 'your_file.csv' with the actual filename or path
data_path = 'files/OWNERSHIP OG DATA.csv'
data_path_updated = 'files/OWNERSHIP UPDATED DATA.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(og_data_path)

df.colunmns
# Out:
#   Title Number     Tenure                                   Property Address  \
# 0      WA44352  Leasehold               94 Rhondda Street, Swansea (SA1 6ET)
# 1      WM16094  Leasehold  55 Raddlebarn Road, Selly Oak, Birmingham (B29...
# 2      WM59658   Freehold      1-40 Old Rectory Gardens, Aldridge, (WS9 8UP)
# 3      WM98474   Freehold  Flats 1 to 12 (inc) and 14 to 52 (inc) Maryval...
# 4     BD153591   Freehold  land and buildings on the North side of Harrol...
#
#                  District         County         Region Postcode  \
# 0                 SWANSEA        SWANSEA          WALES      NaN
# 1              BIRMINGHAM  WEST MIDLANDS  WEST MIDLANDS  B29 6HQ
# 2  WINDSOR AND MAIDENHEAD  WEST MIDLANDS  WEST MIDLANDS  WS9 8UP
# 3                 WALSALL  WEST MIDLANDS  WEST MIDLANDS  WS1 3LP
# 4                 BEDFORD        BEDFORD     SOUTH EAST      NaN
#
#   Multiple Address Indicator  Price Paid                 Proprietor Name (1)  \
# ...

# %%
df = pd.read_csv(data_path_updated)

df.head()
# Out:
#   Title Number     Tenure                                   Property Address  \
# 0      WA44352  Leasehold               94 Rhondda Street, Swansea (SA1 6ET)
# 1      WM16094  Leasehold  55 Raddlebarn Road, Selly Oak, Birmingham (B29...
# 2      WM59658   Freehold      1-40 Old Rectory Gardens, Aldridge, (WS9 8UP)
# 3      WM98474   Freehold  Flats 1 to 12 (inc) and 14 to 52 (inc) Maryval...
# 4     BD153591   Freehold  land and buildings on the North side of Harrol...
#
#                  District         County         Region Postcode  \
# 0                 SWANSEA        SWANSEA          WALES      NaN
# 1              BIRMINGHAM  WEST MIDLANDS  WEST MIDLANDS  B29 6HQ
# 2  WINDSOR AND MAIDENHEAD  WEST MIDLANDS  WEST MIDLANDS  WS9 8UP
# 3                 WALSALL  WEST MIDLANDS  WEST MIDLANDS  WS1 3LP
# 4                 BEDFORD        BEDFORD     SOUTH EAST      NaN
#
#   Multiple Address Indicator  Price Paid                 Proprietor Name (1)  \
# ...
